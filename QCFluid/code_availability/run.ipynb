# %% [markdown]
# #### This script will guide you to generate simulation data for SuppFigS8 and SuppFigS9.
# #### The result files are stored in folder "code_availability/simulation/temp".

# %%
# When import simulation package, a new folder named "temp" will be created automatically.
# At first running, some necessary pickle files will be cached for next running. (This process may cost half an hour.)
from simulation import stripe_pattern, deviation_of_Jy

# %% [markdown]
# Following code will generate "stripe_pattern_q6_error.pkl" and "stripe_pattern_q7_error.pkl" for SuppFigS6.

# %%
stripe_pattern.stripe_pattern_simulation(n_bits=10, error_q_idx=6, save=False)
# stripe_pattern.stripe_pattern_simulation(7, True)
# Out:
# stripe_pattern_simulation 6 False
# sssss
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 77.34it/s]

# %% [markdown]
# Following code will generate "deviation_of_Jy.pkl" for SuppFigS7.

# %%
deviation_of_Jy.deviation_of_Jy_simulation(True)
# Out:
# random seed: 0
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 70.52it/s]
