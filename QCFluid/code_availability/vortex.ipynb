# %%
# When import simulation package, a new folder named "temp" will be created automatically.
# At first running, some necessary pickle files will be cached for next running. (This process may cost half an hour.)
from simulation import vortex

# %%
vortex.stripe_pattern_simulation(-1, True)
# Out:
# stripe_pattern_simulation -1 True
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 81.65it/s]
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 82.30it/s]

# %%
vortex.stripe_pattern_simulation(5, True)
# Out:
# stripe_pattern_simulation 5 True
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 82.49it/s]
# processing sampling result: 100%|██████████| 32/32 [00:00<00:00, 81.75it/s]
