# %% [markdown]
# The qubit index in qasm file follow the convention mentioned in [README.md](../../README.md)

# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit.from_qasm_file('vortex_phi_p_t=0.qasm')

# %%
qc.draw('mpl', fold=60)
